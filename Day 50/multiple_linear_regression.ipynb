# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -0.963542 -0.210375  -68.611800
# 1 -1.295658  0.897190    2.144924
# 2 -0.756375  1.416017   74.780267
# 3 -0.861560 -1.565273 -112.924480
# 4 -0.949746 -0.954528  -80.452092

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 59.07453804134898
# MSE 5018.9842868059895
# R2 score 0.4679429145534785

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
import numpy as np

# 1️⃣ Create grid range based on data (IMPORTANT)
x = np.linspace(df.feature1.min(), df.feature1.max(), 30)
y = np.linspace(df.feature2.min(), df.feature2.max(), 30)

# 2️⃣ Create meshgrid
xGrid, yGrid = np.meshgrid(x, y)

# 3️⃣ Prepare input for model
final = np.vstack((
    xGrid.ravel(),
    yGrid.ravel()
)).T              # shape → (900, 2)

# 4️⃣ Predict (USE PROBABILITY FOR LOGISTIC REGRESSION)
z_final = lr.predict_proba(final)[:, 1]

# 5️⃣ Reshape back to grid
z = z_final.reshape(xGrid.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 17
#      11 final = np.vstack((
#      12     xGrid.ravel(),
#      13     yGrid.ravel()
#      14 )).T              # shape → (900, 2)
#      16 # 4️⃣ Predict (USE PROBABILITY FOR LOGISTIC REGRESSION)
# ---> 17 z_final = lr.predict_proba(final)[:, 1]
#      19 # 5️⃣ Reshape back to grid
#      20 z = z_final.reshape(xGrid.shape)
#
# AttributeError: 'LinearRegression' object has no attribute 'predict_proba'

# %%
print(np.unique(z))
# Out:
# [-555.58580051 -498.89008771 -490.15975765 -442.19437492 -433.46404485
#  -424.73371478 -385.49866212 -376.76833205 -368.03800198 -359.30767191
#  -328.80294932 -320.07261925 -311.34228918 -302.61195911 -293.88162905
#  -272.10723652 -263.37690645 -254.64657638 -245.91624632 -237.18591625
#  -228.45558618 -215.41152372 -206.68119365 -197.95086358 -189.22053352
#  -180.49020345 -171.75987338 -163.02954331 -158.71581092 -149.98548085
#  -141.25515078 -132.52482072 -123.79449065 -115.06416058 -106.33383051
#  -102.02009812  -97.60350045  -93.28976805  -84.55943798  -75.82910792
#   -67.09877785  -58.36844778  -49.63811771  -45.32438532  -40.90778765
#   -36.59405525  -32.17745758  -27.86372519  -19.13339512  -10.40306505
#    -1.67273498    7.05759508   15.78792515   20.10165755   24.51825522
#    28.83198761   33.24858529   37.56231768   46.29264775   55.02297782
#    63.75330788   72.48363795   81.21396802   85.52770041   89.94429809
#    94.25803048  102.98836055  111.71869062  120.44902068  129.17935075
#   137.90968082  146.64001089  150.95374328  159.68407335  168.41440341
#   177.14473348  185.87506355  194.60539362  203.33572368  216.37978615
#   225.11011621  233.84044628  242.57077635  251.30110642  260.03143648
#   281.80582901  290.53615908  299.26648915  307.99681922  316.72714928
#   347.23187188  355.96220195  364.69253201  373.42286208  412.65791475
#   421.38824481  430.11857488  478.08395761  486.81428768  543.51000048]

# %%
import plotly.express as px
import plotly.graph_objects as go

# 3D scatter (actual data points)
fig = px.scatter_3d(
    df,
    x='feature1',
    y='feature2',
    z='target'
)

# Add prediction surface
fig.add_trace(
    go.Surface(
        x=xGrid,
        y=yGrid,
        z=z,
        opacity=0.6
    )
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="a2e6daf9-17b5-4515-a5aa-85d341078fdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a2e6daf9-17b5-4515-a5aa-85d341078fdc")) {                    Plotly.newPlot(                        "a2e6daf9-17b5-4515-a5aa-85d341078fdc",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":{"dtype":"f8","bdata":"Zs6ZblbV7r+O+py9A7v0vyOI5Bc5NOi\u002fVDg1KOeR67\u002f\u002fBw1CUWTuv1p5lfAlSvG\u002fd68MJT1Z4L\u002fpclsv3bG9vxhWMAaVIee\u002f6tTBBQUC\u002fT8GvjA1TgDkv5cg33uj5\u002fa\u002fAwZeVbQf8T9fXD0hVEvlP7puDJ3eDeG\u002fDJBckiNw+L\u002fHZ9twLwTxvzYP2K7hYPS\u002fcGu0cA1J8j9wMvpaeKzOP\u002fJOj1KDpOM\u002fqBNyo\u002fIBxL+MBsZz5iTCP0daVwLX7vC\u002fRTK6ZCZQ2D\u002f3qN9Hhc7pv0qA2UY9KvG\u002fAyzEvymW2L8v3l6Daobyv3a8fcgZzfA\u002f7VeaFqJ24D8VKenrp5Lxv4xijxE2pNU\u002fWD4YTZ\u002fL7j+zDupKBlnHv3\u002fezemoCNE\u002fD0hHfRx49D9nBl8sAqvCv87JzQdf77W\u002fiQMBWqnE+D+v\u002fSJW7YLdvxqyxvXg4Ji\u002fxkPRS3zM4j+815CwF2fYvzzThQV8y\u002fc\u002fleeNeMCQ7r8mzg55U\u002fnxv4aBY\u002f4UYQFAKPfo9dZu9D9aTcw5ySziP0P6Uwk6iMK\u002fdO3T5ChR4T\u002fmmH\u002fMzgT9PwWbFCiXp9C\u002fptDebnA+2b9Ep+24oUjpv1tak6ePJ\u002fg\u002fqR+TR0rP6T+UU6Bxx8jlPx7CjHULQfO\u002f5tQyGDtrwz+tJy3EyYz3P5grPW2kzec\u002fVpm7kzqy2D+eDB63iOT4v9gJRYBG8Pi\u002fRO4fqbES4T\u002f1z+b5QrHyP9Suaj1c3wBA1kRriHwFqL8x2lDjegPUv4d1eEgITfA\u002fPixSPGwbzL\u002fL+5hlOou7v9eA8rA4oPy\u002fp9P0uos58T8zX\u002fl7TYjnPyAq7JcCi9q\u002fBGPWGPtMyT+n8Pia1h\u002fJv+IVXl4tZss\u002f0V0UrUy89z+LTfRqouLAP9Fm3ez5XeK\u002fN9dDu0Vt3T+kzsc4oHr8v6JrcTH8ns0\u002fBb2dRw7g7b\u002fBsLrInK31v3KoX7vgScG\u002fwbtWLbfV+b+jLMvHbl\u002fnv8+Akq1RmOE\u002fc80vsboT1j\u002fK7jJW5LfTP5jQLOb7v\u002fY\u002flBEH4nT76j9+uDke6rjjP7bcRjjAxdk\u002fcU72wYF89D8="},"y":{"dtype":"f8","bdata":"9JXrNJHtyr8Wo6aKx7XsP6ry7coBqPY\u002f4Ndk31sL+b\u002fkUlxofYvuvwE1REn7E\u002fw\u002fjfzvJaKp4z9\u002f+z8ycFkHQMxArr7CFfa\u002fm3gCMva54b+bU7X0arTqv0G6vspYPsk\u002f7tD71ujCzj8s+82K\u002fUHZPy+vT7SfFdy\u002f2IUhEjwh87+8xatXyY\u002flP8sIMgpEv6Y\u002fYS3alJtD4D\u002fIiwdVRmfhv\u002fBIitw3uvI\u002fwUsaoRJD6z\u002f8XVUljhXmP7sQxYqmGvY\u002fl1eFSjwruj\u002f0lRLbRKvwvyqIO6Vs\u002f+8\u002fpTvmJich6j\u002fQkxhia3Ttv09faJ8HQry\u002f34qPzjwd+T+l5RIxVlPyv64jD2l269g\u002fPbsf5pDR4z+oDh\u002fFXP66P9eYjFyHreg\u002fi1J+RMF20r87Di051T+rPyLV+qYzqMu\u002fx3vIYIxvob\u002fYjd9hrPL+P2jhbRPG6QHAuBWS5OZt87975Z73wI3ovyAjEawkK9q\u002foc2nAFGg6r\u002fENnA+tBfdv69NcKhbG9M\u002fdkG3OIpR5z\u002fi9Dibf6bpP8KBCQZYdOs\u002fs\u002fZAUOzR5D\u002f051Hlo9Tav9AQLJKU8e+\u002fA\u002fYyv9\u002fF\u002f7\u002f4VDWIk6LyP48UxVvOZfO\u002fdhhsTYa77r+DA3lBDMDyv8G\u002fhPt4QuK\u002ft2+7PYTb47+GVbdhuBO0v\u002fdwbelbRdY\u002fXy2lBDT4wD+IQ4yWcdvWP+ryMEHXz9C\u002fbKrbZcu67L8Do867NW3wP+J8jb5javi\u002fGGAl\u002ffI57z+HVvIltLHSP5D0gevwzes\u002fCg7VDKVQ9r8h6QwRr2v8P4BYQo+hkfm\u002fZBsoYbuY8b\u002f\u002fcCCjfbzzP2Z7ww019\u002fY\u002fMWFNSj+I0T\u002fswpCSudz2P3s98Xkqgew\u002f7Jzzn7Cp4r+WbObjDqECwDPwu5ArhNu\u002fj4Lnc2XK4j\u002fAR0ST2WjpPyZxbcLG1+Y\u002fOFKKf1x51T9Lz\u002fDRMuPcP2NcVK9GWtU\u002fIf0V+rBx2D9Nlqq8X9WxvxmJmawLr\u002fy\u002f0qZbFDob8j8f8g9Ga0cCQCZn8XuC9+U\u002fQjtkKu0i6r\u002fQ8XCucyy2vyGD0QM8yQJAwUBIsxCT3j8="},"z":{"dtype":"f8","bdata":"IvUVuicnUcDAhRzUzSgBQEoluObvsVJASCH6rSo7XMC5T1oV7xxUwKNnZbtwgixASjpxQHz\u002fRkDv6YCvjpBRQNT0gHsBYGLALrr8524\u002fTkAANWgAkvJcwEdoEljtA1HACBTaCrtwUcBlPGnD8xRPQLAfKsOQbFbAVAreFDihYcChoWm7uyZdwD7VWqjpPVnA5O6pkLyEZEBlSjXt1ZVXQJwEF2N6\u002fFFAau3klQjSPUBgvCwDXmkBQOxJZjFFAvW\u002f28IZ4DlDV0Dyuppn3ThZwBI ...

# %%
lr.coef_
# Out:
# array([58.88343858, 51.02614152])

# %%
lr.intercept_
# Out:
# np.float64(-6.037900016753756)
